# %% [markdown]
# # Hyperparameter Optimisation Tutorial
#
# https://www.youtube.com/watch?v=5nYqK-HaoKY&t=2923s

# %%
import pandas as pd
import numpy as np

from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics

from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('./mobile_price_range_data.csv')
df.head(10)
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
# 5           1859     0          0.5         1   3       0          22    0.7
# 6           1821     0          1.7         0   4       1          10    0.8
# 7           1954     0          0.5         1   0       0          24    0.8
# 8           1445     1          0.5         0   0       0          53    0.7
# 9            509     1          0.6         1   2       1           9    0.1
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
# 5        164        1  ...       1004      1654  1067    17     1         10
# 6        139        8  ...        381      1018  3220    13     8         18
# 7        187        4  ...        512      1149   700    16     3          5
# 8        174        7  ...        386       836  1099    17     1         20
# 9         93        5  ...       1137      1224   513    19    10         12
#
#    three_g  touch_screen  wifi  price_range
# 0        0             0     1            1
# 1        1             1     0            2
# 2        1             1     0            2
# 3        1             0     0            2
# 4        1             1     0            1
# 5        1             0     0            1
# 6        1             0     1            3
# 7        1             1     1            0
# 8        1             0     0            0
# 9        1             0     0            0
#
# [10 rows x 21 columns]

# %%
# numpy arrays of features
X = df.drop('price_range', axis=1).values
y = df['price_range'].values

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=1223)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (1700, 20) (300, 20) (1700,) (300,)

# %% [markdown]
# ## Grid Search

# %%
from sklearn.model_selection import GridSearchCV

classifier = RandomForestClassifier(n_jobs=-1)
param_grid = {
    'n_estimators': [100, 200, 300, 400],
    'max_depth': [1, 3, 5, 7],
    'criterion': ['gini', 'entropy']
}

model = GridSearchCV(
    estimator=classifier,
    param_grid=param_grid,
    scoring='accuracy',
    verbose=10,
    cv=5
)

model.fit(X_train, y_train)

print("best score " + str(model.best_score_))

print('best params')
print(model.best_estimator_.get_params())
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# [CV 1/5; 1/32] START criterion=gini, max_depth=1, n_estimators=100..............
# [CV 1/5; 1/32] END criterion=gini, max_depth=1, n_estimators=100;, score=0.647 total time=   8.1s
# [CV 2/5; 1/32] START criterion=gini, max_depth=1, n_estimators=100..............
# [CV 2/5; 1/32] END criterion=gini, max_depth=1, n_estimators=100;, score=0.662 total time=   0.1s
# [CV 3/5; 1/32] START criterion=gini, max_depth=1, n_estimators=100..............
# [CV 3/5; 1/32] END criterion=gini, max_depth=1, n_estimators=100;, score=0.641 total time=   0.0s
# [CV 4/5; 1/32] START criterion=gini, max_depth=1, n_estimators=100..............
# [CV 4/5; 1/32] END criterion=gini, max_depth=1, n_estimators=100;, score=0.653 total time=   0.0s
# [CV 5/5; 1/32] START criterion=gini, max_depth=1, n_estimators=100..............
# [CV 5/5; 1/32] END criterion=gini, max_depth=1, n_estimators=100;, score=0.594 total time=   0.0s
# [CV 1/5; 2/32] START criterion=gini, max_depth=1, n_estimators=200..............
# [CV 1/5; 2/32] END criterion=gini, max_depth=1, n_estimators=200;, score=0.597 total time=   0.1s
# [CV 2/5; 2/32] START criterion=gini, max_depth=1, n_estimators=200..............
# [CV 2/5; 2/32] END criterion=gini, max_depth=1, n_estimators=200;, score=0.682 total time=   0.2s
# [CV 3/5; 2/32] START criterion=gini, max_depth=1, n_estimators=200..............
# [CV 3/5; 2/32] END criterion=gini, max_depth=1, n_estimators=200;, score=0.600 total time=   0.1s
# [CV 4/5; 2/32] START criterion=gini, max_depth=1, n_estimators=200..............
# [CV 4/5; 2/32] END criterion=gini, max_depth=1, n_estimators=200;, score=0.700 total time=   0.1s
# [CV 5/5; 2/32] START criterion=gini, max_depth=1, n_estimators=200..............
# [CV 5/5; 2/32] END criterion=gini, max_depth=1, n_estimators=200;, score=0.556 total time=   0.1s
# [CV 1/5; 3/32] START criterion=gini, max_depth=1, n_estimators=300..............
# [CV 1/5; 3/32] END criterion=gini, max_depth=1, n_estimators=300;, score=0.618 total time=   0.4s
# [CV 2/5; 3/32] START criterion=gini, max_depth=1, n_estimators=300..............
# [CV 2/5; 3/32] END criterion=gini, max_depth=1, n_estimators=300;, score=0.691 total time=   0.3s
# [CV 3/5; 3/32] START criterion=gini, max_depth=1, n_estimators=300..............
# [CV 3/5; 3/32] END criterion=gini, max_depth=1, n_estimators=300;, score=0.597 total time=   0.3s
# [CV 4/5; 3/32] START criterion=gini, max_depth=1, n_estimators=300..............
# [CV 4/5; 3/32] END criterion=gini, max_depth=1, n_estimators=300;, score=0.609 total time=   0.4s
# [CV 5/5; 3/32] START criterion=gini, max_depth=1, n_estimators=300..............
# [CV 5/5; 3/32] END criterion=gini, max_depth=1, n_estimators=300;, score=0.568 total time=   0.3s
# [CV 1/5; 4/32] START criterion=gini, max_depth=1, n_estimators=400..............
# [CV 1/5; 4/32] END criterion=gini, max_depth=1, n_estimators=400;, score=0.650 total time=   0.4s
# [CV 2/5; 4/32] START criterion=gini, max_depth=1, n_estimators=400..............
# [CV 2/5; 4/32] END criterion=gini, max_depth=1, n_estimators=400;, score=0.674 total time=   0.5s
# [CV 3/5; 4/32] START criterion=gini, max_depth=1, n_estimators=400..............
# [CV 3/5; 4/32] END criterion=gini, max_depth=1, n_estimators=400;, score=0.594 total time=   0.5s
# [CV 4/5; 4/32] START criterion=gini, max_depth=1, n_estimators=400..............
# [CV 4/5; 4/32] END criterion=gini, max_depth=1, n_estimators=400;, score=0.647 total time=   0.4s
# [CV 5/5; 4/32] START criterion=gini, max_depth=1, n_estimators=400..............
# [CV 5/5; 4/32] END criterion=gini, max_depth=1, n_estimators=400;, score=0.550 total time=   0.4s
# [CV 1/5; 5/32] START criterion=gini, max_depth=3, n_estimators=100..............
# [CV 1/5; 5/32] END criterion=gini, max_depth=3, n_estimators=100;, score=0.806 total time=   0.1s
# [CV 2/5; 5/32] START criterion=gini, max_depth=3, n_estimators=100..............
# [CV 2/5; 5/32] END criterion=gini, max_depth=3, n_estimators=100;, score=0.788 total time=   0.1s
# [CV 3/5; 5/32] START criterion=gini, max_depth=3, n_estimators=100..............
# [CV 3/5; 5/32] END criterion=gini, max_depth=3, n_estimators=100;, score=0.776 total time=   0.1s
# [CV 4/5; 5/32] START criterion=gini, max_depth=3, n_estimators=100..............
# [CV 4/5; 5/32] END criterion=gini, max_depth=3, n_estimators=100;, score=0.815 total time=   0.1s
# [CV 5/5; 5/32] START criterion=gini, max_depth=3, n_estimators=100..............
# [CV 5/5; 5/32] END criterion=gini, max_depth=3, n_estimators=100;, score=0.803 total time=   0.1s
# [CV 1/5; 6/32] START criterion=gini, max_depth=3, n_estimators=200..............
# [CV 1/5; 6/32] END criterion=gini, max_depth=3, n_estimators=200;, score=0.824 total time=   0.2s
# [CV 2/5; 6/32] START criterion=gini, max_depth=3, n_estimators=200..............
# [CV 2/5; 6/32] END criterion=gini, max_depth=3, n_estimators=200;, score=0.788 total time=   0.3s
# [CV 3/5; 6/32] START criterion=gini, max_depth=3, n_estimators=200..............
# [CV 3/5; 6/32] END criterion=gini, max_depth=3, n_estimators=200;, score=0.788 total time=   0.2s
# [CV 4/5; 6/32] START criterion=gini, max_depth=3, n_estimators=200..............
# [CV 4/5; 6/32] END criterion=gini, max_depth=3, n_estimators=200;, score=0.806 total time=   0.3s
# [CV 5/5; 6/32] START criterion=gini, max_depth=3, n_estimators=200..............
# [CV 5/5; 6/32] END criterion=gini, max_depth=3, n_estimators=200;, score=0.797 total time=   0.2s
# [CV 1/5; 7/32] START criterion=gini, max_depth=3, n_estimators=300..............
# [CV 1/5; 7/32] END criterion=gini, max_depth=3, n_estimators=300;, score=0.812 total time=   0.4s
# [CV 2/5; 7/32] START criterion=gini, max_depth=3, n_estimators=300..............
# [CV 2/5; 7/32] END criterion=gini, max_depth=3, n_estimators=300;, score=0.774 total time=   0.4s
# [CV 3/5; 7/32] START criterion=gini, max_depth=3, n_estimators=300..............
# [CV 3/5; 7/32] END criterion=gini, max_depth=3, n_estimators=300;, score=0.774 total time=   0.4s
# [CV 4/5; 7/32] START criterion=gini, max_depth=3, n_estimators=300..............
# [CV 4/5; 7/32] END criterion=gini, max_depth=3, n_estimators=300;, score=0.809 total time=   0.4s
# [CV 5/5; 7/32] START criterion=gini, max_depth=3, n_estimators=300..............
# [CV 5/5; 7/32] END criterion=gini, max_depth=3, n_estimators=300;, score=0.794 total time=   0.4s
# [CV 1/5; 8/32] START criterion=gini, max_depth=3, n_estimators=400..............
# [CV 1/5; 8/32] END criterion=gini, max_depth=3, n_estimators=400;, score=0.800 total time=   1.0s
# [CV 2/5; 8/32] START criterion=gini, max_depth=3, n_estimators=400..............
# [CV 2/5; 8/32] END criterion=gini, max_depth=3, n_estimators=400;, score=0.788 total time=   1.2s
# [CV 3/5; 8/32] START criterion=gini, max_depth=3, n_estimators=400..............
# [CV 3/5; 8/32] END criterion=gini, max_depth=3, n_estimators=400;, score=0.776 total time=   0.9s
# [CV 4/5; 8/32] START criterion=gini, max_depth=3, n_estimators=400..............
# [CV 4/5; 8/32] END criterion=gini, max_depth=3, n_estimators=400;, score=0.821 total time=   0.6s
# [CV 5/5; 8/32] START criterion=gini, max_depth=3, n_estimators=400..............
# [CV 5/5; 8/32] END criterion=gini, max_depth=3, n_estimators=400;, score=0.800 total time=   0.9s
# [CV 1/5; 9/32] START criterion=gini, max_depth=5, n_estimators=100..............
# [CV 1/5; 9/32] END criterion=gini, max_depth=5, n_estimators=100;, score=0.826 total time=   0.3s
# [CV 2/5; 9/32] START criterion=gini, max_depth=5, n_estimators=100..............
# [CV 2/5; 9/32] END criterion=gini, max_depth=5, n_estimators=100;, score=0.841 total time=   0.2s
# [CV 3/5; 9/32] START criterion=gini, max_depth=5, n_estimators=100..............
# [CV 3/5; 9/32] END criterion=gini, max_depth=5, n_estimators=100;, score=0.815 total time=   0.1s
# [CV 4/5; 9/32] START criterion=gini, max_depth=5, n_estimators=100..............
# [CV 4/5; 9/32] END criterion=gini, max_depth=5, n_estimators=100;, score=0.826 total time=   0.1s
# [CV 5/5; 9/32] START criterion=gini, max_depth=5, n_estimators=100..............
# [CV 5/5; 9/32] END criterion=gini, max_depth=5, n_estimators=100;, score=0.821 total time=   0.1s
# [CV 1/5; 10/32] START criterion=gini, max_depth=5, n_estimators=200.............
# [CV 1/5; 10/32] END criterion=gini, max_depth=5, n_estimators=200;, score=0.826 total time=   0.3s
# [CV 2/5; 10/32] START criterion=gini, max_depth=5, n_estimators=200.............
# [CV 2/5; 10/32] END criterion=gini, max_depth=5, n_estimators=200;, score=0.812 total time=   0.3s
# [CV 3/5; 10/32] START criterion=gini, max_depth=5, n_estimators=200.............
# [CV 3/5; 10/32] END criterion=gini, max_depth=5, n_estimators=200;, score=0.818 total time=   0.3s
# [CV 4/5; 10/32] START criterion=gini, max_depth=5, n_estimators=200.............
# [CV 4/5; 10/32] END criterion=gini, max_depth=5, n_estimators=200;, score=0.859 total time=   0.3s
# [CV 5/5; 10/32] START criterion=gini, max_depth=5, n_estimators=200.............
# [CV 5/5; 10/32] END criterion=gini, max_depth=5, n_estimators=200;, score=0.829 total time=   0.3s
# [CV 1/5; 11/32] START criterion=gini, max_depth=5, n_estimators=300.............
# [CV 1/5; 11/32] END criterion=gini, max_depth=5, n_estimators=300;, score=0.838 total time=   0.6s
# [CV 2/5; 11/32] START criterion=gini, max_depth=5, n_estimators=300.............
# [CV 2/5; 11/32] END criterion=gini, max_depth=5, n_estimators=300;, score=0.818 total time=   0.5s
# [CV 3/5; 11/32] START criterion=gini, max_depth=5, n_estimators=300.............
# [CV 3/5; 11/32] END criterion=gini, max_depth=5, n_estimators=300;, score=0.821 total time=   0.8s
# [CV 4/5; 11/32] START criterion=gini, max_depth=5, n_estimators=300.............
# [CV 4/5; 11/32] END criterion=gini, max_depth=5, n_estimators=300;, score=0.829 total time=   0.7s
# [CV 5/5; 11/32] START criterion=gini, max_depth=5, n_estimators=300.............
# [CV 5/5; 11/32] END criterion=gini, max_depth=5, n_estimators=300;, score=0.832 total time=   0.5s
# [CV 1/5; 12/32] START criterion=gini, max_depth=5, n_estimators=400.............
# [CV 1/5; 12/32] END criterion=gini, max_depth=5, n_estimators=400;, score=0.847 total time=   0.7s
# [CV 2/5; 12/32] START criterion=gini, max_depth=5, n_estimators=400.............
# [CV 2/5; 12/32] END criterion=gini, max_depth=5, n_estimators=400;, score=0.812 total time=   0.6s
# [CV 3/5; 12/32] START criterion=gini, max_depth=5, n_estimators=400.............
# [CV 3/5; 12/32] END criterion=gini, max_depth=5, n_estimators=400;, score=0.826 total time=   0.7s
# [CV 4/5; 12/32] START criterion=gini, max_depth=5, n_estimators=400.............
# [CV 4/5; 12/32] END criterion=gini, max_depth=5, n_estimators=400;, score=0.856 total time=   0.6s
# [CV 5/5; 12/32] START criterion=gini, max_depth=5, n_estimators=400.............
# [CV 5/5; 12/32] END criterion=gini, max_depth=5, n_estimators=400;, score=0.829 total time=   0.6s
# [CV 1/5; 13/32] START criterion=gini, max_depth=7, n_estimators=100.............
# [CV 1/5; 13/32] END criterion=gini, max_depth=7, n_estimators=100;, score=0.853 total time=   0.1s
# [CV 2/5; 13/32] START criterion=gini, max_depth=7, n_estimators=100.............
# [CV 2/5; 13/32] END criterion=gini, max_depth=7, n_estimators=100;, score=0.862 total time=   0.2s
# [CV 3/5; 13/32] START criterion=gini, max_depth=7, n_estimators=100.............
# [CV 3/5; 13/32] END criterion=gini, max_depth=7, n_estimators=100;, score=0.853 total time=   0.2s
# [CV 4/5; 13/32] START criterion=gini, max_depth=7, n_estimators=100.............
# [CV 4/5; 13/32] END criterion=gini, max_depth=7, n_estimators=100;, score=0.871 total time=   0.1s
# [CV 5/5; 13/32] START criterion=gini, max_depth=7, n_estimators=100.............
# [CV 5/5; 13/32] END criterion=gini, max_depth=7, n_estimators=100;, score=0.859 total time=   0.1s
# [CV 1/5; 14/32] START criterion=gini, max_depth=7, n_estimators=200.............
# [CV 1/5; 14/32] END criterion=gini, max_depth=7, n_estimators=200;, score=0.876 total time=   0.3s
# [CV 2/5; 14/32] START criterion=gini, max_depth=7, n_estimators=200.............
# [CV 2/5; 14/32] END criterion=gini, max_depth=7, n_estimators=200;, score=0.859 total time=   0.4s
# [CV 3/5; 14/32] START criterion=gini, max_depth=7, n_estimators=200.............
# [CV 3/5; 14/32] END criterion=gini, max_depth=7, n_estimators=200;, score=0.850 total time=   0.3s
# [CV 4/5; 14/32] START criterion=gini, max_depth=7, n_estimators=200.............
# [CV 4/5; 14/32] END criterion=gini, max_depth=7, n_estimators=200;, score=0.862 total time=   0.3s
# [CV 5/5; 14/32] START criterion=gini, max_depth=7, n_estimators=200.............
# [CV 5/5; 14/32] END criterion=gini, max_depth=7, n_estimators=200;, score=0.853 total time=   0.3s
# [CV 1/5; 15/32] START criterion=gini, max_depth=7, n_estimators=300.............
# [CV 1/5; 15/32] END criterion=gini, max_depth=7, n_estimators=300;, score=0.862 total time=   0.5s
# [CV 2/5; 15/32] START criterion=gini, max_depth=7, n_estimators=300.............
# [CV 2/5; 15/32] END criterion=gini, max_depth=7, n_estimators=300;, score=0.835 total time=   0.6s
# [CV 3/5; 15/32] START criterion=gini, max_depth=7, n_estimators=300.............
# [CV 3/5; 15/32] END criterion=gini, max_depth=7, n_estimators=300;, score=0.853 total time=   0.5s
# [CV 4/5; 15/32] START criterion=gini, max_depth=7, n_estimators=300.............
# [CV 4/5; 15/32] END criterion=gini, max_depth=7, n_estimators=300;, score=0.868 total time=   0.5s
# [CV 5/5; 15/32] START criterion=gini, max_depth=7, n_estimators=300.............
# [CV 5/5; 15/32] END criterion=gini, max_depth=7, n_estimators=300;, score=0.835 total time=   0.5s
# [CV 1/5; 16/32] START criterion=gini, max_depth=7, n_estimators=400.............
# [CV 1/5; 16/32] END criterion=gini, max_depth=7, n_estimators=400;, score=0.874 total time=   0.6s
# [CV 2/5; 16/32] START criterion=gini, max_depth=7, n_estimators=400.............
# [CV 2/5; 16/32] END criterion=gini, max_depth=7, n_estimators=400;, score=0.859 total time=   0.7s
# [CV 3/5; 16/32] START criterion=gini, max_depth=7, n_estimators=400.............
# [CV 3/5; 16/32] END criterion=gini, max_depth=7, n_estimators=400;, score=0.847 total time=   0.6s
# [CV 4/5; 16/32] START criterion=gini, max_depth=7, n_estimators=400.............
# [CV 4/5; 16/32] END criterion=gini, max_depth=7, n_estimators=400;, score=0.865 total time=   0.6s
# [CV 5/5; 16/32] START criterion=gini, max_depth=7, n_estimators=400.............
# [CV 5/5; 16/32] END criterion=gini, max_depth=7, n_estimators=400;, score=0.844 total time=   0.7s
# [CV 1/5; 17/32] START criterion=entropy, max_depth=1, n_estimators=100..........
# [CV 1/5; 17/32] END criterion=entropy, max_depth=1, n_estimators=100;, score=0.547 total time=   0.1s
# [CV 2/5; 17/32] START criterion=entropy, max_depth=1, n_estimators=100..........
# [CV 2/5; 17/32] END criterion=entropy, max_depth=1, n_estimators=100;, score=0.585 total time=   0.1s
# [CV 3/5; 17/32] START criterion=entropy, max_depth=1, n_estimators=100..........
# [CV 3/5; 17/32] END criterion=entropy, max_depth=1, n_estimators=100;, score=0.532 total time=   0.1s
# [CV 4/5; 17/32] START criterion=entropy, max_depth=1, n_estimators=100..........
# [CV 4/5; 17/32] END criterion=entropy, max_depth=1, n_estimators=100;, score=0.559 total time=   0.1s
# [CV 5/5; 17/32] START criterion=entropy, max_depth=1, n_estimators=100..........
# [CV 5/5; 17/32] END criterion=entropy, max_depth=1, n_estimators=100;, score=0.512 total time=   0.1s
# [CV 1/5; 18/32] START criterion=entropy, max_depth=1, n_estimators=200..........
# [CV 1/5; 18/32] END criterion=entropy, max_depth=1, n_estimators=200;, score=0.544 total time=   0.2s
# [CV 2/5; 18/32] START criterion=entropy, max_depth=1, n_estimators=200..........
# [CV 2/5; 18/32] END criterion=entropy, max_depth=1, n_estimators=200;, score=0.550 total time=   0.2s
# [CV 3/5; 18/32] START criterion=entropy, max_depth=1, n_estimators=200..........
# [CV 3/5; 18/32] END criterion=entropy, max_depth=1, n_estimators=200;, score=0.585 total time=   0.2s
# [CV 4/5; 18/32] START criterion=entropy, max_depth=1, n_estimators=200..........
# [CV 4/5; 18/32] END criterion=entropy, max_depth=1, n_estimators=200;, score=0.568 total time=   0.2s
# [CV 5/5; 18/32] START criterion=entropy, max_depth=1, n_estimators=200..........
# [CV 5/5; 18/32] END criterion=entropy, max_depth=1, n_estimators=200;, score=0.538 total time=   0.2s
# [CV 1/5; 19/32] START criterion=entropy, max_depth=1, n_estimators=300..........
# [CV 1/5; 19/32] END criterion=entropy, max_depth=1, n_estimators=300;, score=0.538 total time=   0.3s
# [CV 2/5; 19/32] START criterion=entropy, max_depth=1, n_estimators=300..........
# [CV 2/5; 19/32] END criterion=entropy, max_depth=1, n_estimators=300;, score=0.550 total time=   0.3s
# [CV 3/5; 19/32] START criterion=entropy, max_depth=1, n_estimators=300..........
# [CV 3/5; 19/32] END criterion=entropy, max_depth=1, n_estimators=300;, score=0.562 total time=   0.3s
# [CV 4/5; 19/32] START criterion=entropy, max_depth=1, n_estimators=300..........
# [CV 4/5; 19/32] END criterion=entropy, max_depth=1, n_estimators=300;, score=0.559 total time=   0.3s
# [CV 5/5; 19/32] START criterion=entropy, max_depth=1, n_estimators=300..........
# [CV 5/5; 19/32] END criterion=entropy, max_depth=1, n_estimators=300;, score=0.521 total time=   0.3s
# [CV 1/5; 20/32] START criterion=entropy, max_depth=1, n_estimators=400..........
# [CV 1/5; 20/32] END criterion=entropy, max_depth=1, n_estimators=400;, score=0.535 total time=   0.5s
# [CV 2/5; 20/32] START criterion=entropy, max_depth=1, n_estimators=400..........
# [CV 2/5; 20/32] END criterion=entropy, max_depth=1, n_estimators=400;, score=0.562 total time=   0.9s
# [CV 3/5; 20/32] START criterion=entropy, max_depth=1, n_estimators=400..........
# [CV 3/5; 20/32] END criterion=entropy, max_depth=1, n_estimators=400;, score=0.562 total time=   1.5s
# [CV 4/5; 20/32] START criterion=entropy, max_depth=1, n_estimators=400..........
# [CV 4/5; 20/32] END criterion=entropy, max_depth=1, n_estimators=400;, score=0.553 total time=   1.0s
# [CV 5/5; 20/32] START criterion=entropy, max_depth=1, n_estimators=400..........
# [CV 5/5; 20/32] END criterion=entropy, max_depth=1, n_estimators=400;, score=0.538 total time=   1.1s
# [CV 1/5; 21/32] START criterion=entropy, max_depth=3, n_estimators=100..........
# [CV 1/5; 21/32] END criterion=entropy, max_depth=3, n_estimators=100;, score=0.747 total time=   0.5s
# [CV 2/5; 21/32] START criterion=entropy, max_depth=3, n_estimators=100..........
# [CV 2/5; 21/32] END criterion=entropy, max_depth=3, n_estimators=100;, score=0.768 total time=   0.2s
# [CV 3/5; 21/32] START criterion=entropy, max_depth=3, n_estimators=100..........
# [CV 3/5; 21/32] END criterion=entropy, max_depth=3, n_estimators=100;, score=0.800 total time=   0.1s
# [CV 4/5; 21/32] START criterion=entropy, max_depth=3, n_estimators=100..........
# [CV 4/5; 21/32] END criterion=entropy, max_depth=3, n_estimators=100;, score=0.788 total time=   0.1s
# [CV 5/5; 21/32] START criterion=entropy, max_depth=3, n_estimators=100..........
# [CV 5/5; 21/32] END criterion=entropy, max_depth=3, n_estimators=100;, score=0.759 total time=   0.2s
# [CV 1/5; 22/32] START criterion=entropy, max_depth=3, n_estimators=200..........
# [CV 1/5; 22/32] END criterion=entropy, max_depth=3, n_estimators=200;, score=0.771 total time=   0.3s
# [CV 2/5; 22/32] START criterion=entropy, max_depth=3, n_estimators=200..........
# [CV 2/5; 22/32] END criterion=entropy, max_depth=3, n_estimators=200;, score=0.782 total time=   0.3s
# [CV 3/5; 22/32] START criterion=entropy, max_depth=3, n_estimators=200..........
# [CV 3/5; 22/32] END criterion=entropy, max_depth=3, n_estimators=200;, score=0.765 total time=   0.4s
# [CV 4/5; 22/32] START criterion=entropy, max_depth=3, n_estimators=200..........
# [CV 4/5; 22/32] END criterion=entropy, max_depth=3, n_estimators=200;, score=0.806 total time=   0.3s
# [CV 5/5; 22/32] START criterion=entropy, max_depth=3, n_estimators=200..........
# [CV 5/5; 22/32] END criterion=entropy, max_depth=3, n_estimators=200;, score=0.718 total time=   0.4s
# [CV 1/5; 23/32] START criterion=entropy, max_depth=3, n_estimators=300..........
# [CV 1/5; 23/32] END criterion=entropy, max_depth=3, n_estimators=300;, score=0.785 total time=   0.6s
# [CV 2/5; 23/32] START criterion=entropy, max_depth=3, n_estimators=300..........
# [CV 2/5; 23/32] END criterion=entropy, max_depth=3, n_estimators=300;, score=0.794 total time=   0.6s
# [CV 3/5; 23/32] START criterion=entropy, max_depth=3, n_estimators=300..........
# [CV 3/5; 23/32] END criterion=entropy, max_depth=3, n_estimators=300;, score=0.756 total time=   0.6s
# [CV 4/5; 23/32] START criterion=entropy, max_depth=3, n_estimators=300..........
# [CV 4/5; 23/32] END criterion=entropy, max_depth=3, n_estimators=300;, score=0.800 total time=   0.5s
# [CV 5/5; 23/32] START criterion=entropy, max_depth=3, n_estimators=300..........
# [CV 5/5; 23/32] END criterion=entropy, max_depth=3, n_estimators=300;, score=0.765 total time=   0.5s
# [CV 1/5; 24/32] START criterion=entropy, max_depth=3, n_estimators=400..........
# [CV 1/5; 24/32] END criterion=entropy, max_depth=3, n_estimators=400;, score=0.782 total time=   0.6s
# [CV 2/5; 24/32] START criterion=entropy, max_depth=3, n_estimators=400..........
# [CV 2/5; 24/32] END criterion=entropy, max_depth=3, n_estimators=400;, score=0.782 total time=   0.7s
# [CV 3/5; 24/32] START criterion=entropy, max_depth=3, n_estimators=400..........
# [CV 3/5; 24/32] END criterion=entropy, max_depth=3, n_estimators=400;, score=0.771 total time=   0.5s
# [CV 4/5; 24/32] START criterion=entropy, max_depth=3, n_estimators=400..........
# [CV 4/5; 24/32] END criterion=entropy, max_depth=3, n_estimators=400;, score=0.779 total time=   0.6s
# [CV 5/5; 24/32] START criterion=entropy, max_depth=3, n_estimators=400..........
# [CV 5/5; 24/32] END criterion=entropy, max_depth=3, n_estimators=400;, score=0.729 total time=   0.7s
# [CV 1/5; 25/32] START criterion=entropy, max_depth=5, n_estimators=100..........
# [CV 1/5; 25/32] END criterion=entropy, max_depth=5, n_estimators=100;, score=0.838 total time=   0.3s
# [CV 2/5; 25/32] START criterion=entropy, max_depth=5, n_estimators=100..........
# [CV 2/5; 25/32] END criterion=entropy, max_depth=5, n_estimators=100;, score=0.844 total time=   0.3s
# [CV 3/5; 25/32] START criterion=entropy, max_depth=5, n_estimators=100..........
# [CV 3/5; 25/32] END criterion=entropy, max_depth=5, n_estimators=100;, score=0.821 total time=   0.2s
# [CV 4/5; 25/32] START criterion=entropy, max_depth=5, n_estimators=100..........
# [CV 4/5; 25/32] END criterion=entropy, max_depth=5, n_estimators=100;, score=0.850 total time=   0.1s
# [CV 5/5; 25/32] START criterion=entropy, max_depth=5, n_estimators=100..........
# [CV 5/5; 25/32] END criterion=entropy, max_depth=5, n_estimators=100;, score=0.818 total time=   0.1s
# [CV 1/5; 26/32] START criterion=entropy, max_depth=5, n_estimators=200..........
# [CV 1/5; 26/32] END criterion=entropy, max_depth=5, n_estimators=200;, score=0.856 total time=   0.4s
# [CV 2/5; 26/32] START criterion=entropy, max_depth=5, n_estimators=200..........
# [CV 2/5; 26/32] END criterion=entropy, max_depth=5, n_estimators=200;, score=0.838 total time=   0.3s
# [CV 3/5; 26/32] START criterion=entropy, max_depth=5, n_estimators=200..........
# [CV 3/5; 26/32] END criterion=entropy, max_depth=5, n_estimators=200;, score=0.829 total time=   0.3s
# [CV 4/5; 26/32] START criterion=entropy, max_depth=5, n_estimators=200..........
# [CV 4/5; 26/32] END criterion=entropy, max_depth=5, n_estimators=200;, score=0.838 total time=   0.4s
# [CV 5/5; 26/32] START criterion=entropy, max_depth=5, n_estimators=200..........
# [CV 5/5; 26/32] END criterion=entropy, max_depth=5, n_estimators=200;, score=0.832 total time=   0.4s
# [CV 1/5; 27/32] START criterion=entropy, max_depth=5, n_estimators=300..........
# [CV 1/5; 27/32] END criterion=entropy, max_depth=5, n_estimators=300;, score=0.853 total time=   0.6s
# [CV 2/5; 27/32] START criterion=entropy, max_depth=5, n_estimators=300..........
# [CV 2/5; 27/32] END criterion=entropy, max_depth=5, n_estimators=300;, score=0.826 total time=   0.5s
# [CV 3/5; 27/32] START criterion=entropy, max_depth=5, n_estimators=300..........
# [CV 3/5; 27/32] END criterion=entropy, max_depth=5, n_estimators=300;, score=0.826 total time=   0.5s
# [CV 4/5; 27/32] START criterion=entropy, max_depth=5, n_estimators=300..........
# [CV 4/5; 27/32] END criterion=entropy, max_depth=5, n_estimators=300;, score=0.853 total time=   0.6s
# [CV 5/5; 27/32] START criterion=entropy, max_depth=5, n_estimators=300..........
# [CV 5/5; 27/32] END criterion=entropy, max_depth=5, n_estimators=300;, score=0.821 total time=   0.6s
# [CV 1/5; 28/32] START criterion=entropy, max_depth=5, n_estimators=400..........
# [CV 1/5; 28/32] END criterion=entropy, max_depth=5, n_estimators=400;, score=0.847 total time=   0.8s
# [CV 2/5; 28/32] START criterion=entropy, max_depth=5, n_estimators=400..........
# [CV 2/5; 28/32] END criterion=entropy, max_depth=5, n_estimators=400;, score=0.850 total time=   0.8s
# [CV 3/5; 28/32] START criterion=entropy, max_depth=5, n_estimators=400..........
# [CV 3/5; 28/32] END criterion=entropy, max_depth=5, n_estimators=400;, score=0.829 total time=   1.2s
# [CV 4/5; 28/32] START criterion=entropy, max_depth=5, n_estimators=400..........
# [CV 4/5; 28/32] END criterion=entropy, max_depth=5, n_estimators=400;, score=0.850 total time=   0.9s
# [CV 5/5; 28/32] START criterion=entropy, max_depth=5, n_estimators=400..........
# [CV 5/5; 28/32] END criterion=entropy, max_depth=5, n_estimators=400;, score=0.829 total time=   0.8s
# [CV 1/5; 29/32] START criterion=entropy, max_depth=7, n_estimators=100..........
# [CV 1/5; 29/32] END criterion=entropy, max_depth=7, n_estimators=100;, score=0.876 total time=   0.2s
# [CV 2/5; 29/32] START criterion=entropy, max_depth=7, n_estimators=100..........
# [CV 2/5; 29/32] END criterion=entropy, max_depth=7, n_estimators=100;, score=0.856 total time=   0.2s
# [CV 3/5; 29/32] START criterion=entropy, max_depth=7, n_estimators=100..........
# [CV 3/5; 29/32] END criterion=entropy, max_depth=7, n_estimators=100;, score=0.844 total time=   0.3s
# [CV 4/5; 29/32] START criterion=entropy, max_depth=7, n_estimators=100..........
# [CV 4/5; 29/32] END criterion=entropy, max_depth=7, n_estimators=100;, score=0.871 total time=   0.3s
# [CV 5/5; 29/32] START criterion=entropy, max_depth=7, n_estimators=100..........
# [CV 5/5; 29/32] END criterion=entropy, max_depth=7, n_estimators=100;, score=0.865 total time=   0.2s
# [CV 1/5; 30/32] START criterion=entropy, max_depth=7, n_estimators=200..........
# [CV 1/5; 30/32] END criterion=entropy, max_depth=7, n_estimators=200;, score=0.868 total time=   0.6s
# [CV 2/5; 30/32] START criterion=entropy, max_depth=7, n_estimators=200..........
# [CV 2/5; 30/32] END criterion=entropy, max_depth=7, n_estimators=200;, score=0.865 total time=   0.8s
# [CV 3/5; 30/32] START criterion=entropy, max_depth=7, n_estimators=200..........
# [CV 3/5; 30/32] END criterion=entropy, max_depth=7, n_estimators=200;, score=0.859 total time=   1.1s
# [CV 4/5; 30/32] START criterion=entropy, max_depth=7, n_estimators=200..........
# [CV 4/5; 30/32] END criterion=entropy, max_depth=7, n_estimators=200;, score=0.885 total time=   1.1s
# [CV 5/5; 30/32] START criterion=entropy, max_depth=7, n_estimators=200..........
# [CV 5/5; 30/32] END criterion=entropy, max_depth=7, n_estimators=200;, score=0.859 total time=   0.8s
# [CV 1/5; 31/32] START criterion=entropy, max_depth=7, n_estimators=300..........
# [CV 1/5; 31/32] END criterion=entropy, max_depth=7, n_estimators=300;, score=0.871 total time=   1.2s
# [CV 2/5; 31/32] START criterion=entropy, max_depth=7, n_estimators=300..........
# [CV 2/5; 31/32] END criterion=entropy, max_depth=7, n_estimators=300;, score=0.865 total time=   1.0s
# [CV 3/5; 31/32] START criterion=entropy, max_depth=7, n_estimators=300..........
# [CV 3/5; 31/32] END criterion=entropy, max_depth=7, n_estimators=300;, score=0.856 total time=   0.9s
# [CV 4/5; 31/32] START criterion=entropy, max_depth=7, n_estimators=300..........
# [CV 4/5; 31/32] END criterion=entropy, max_depth=7, n_estimators=300;, score=0.882 total time=   0.6s
# [CV 5/5; 31/32] START criterion=entropy, max_depth=7, n_estimators=300..........
# [CV 5/5; 31/32] END criterion=entropy, max_depth=7, n_estimators=300;, score=0.853 total time=   0.5s
# [CV 1/5; 32/32] START criterion=entropy, max_depth=7, n_estimators=400..........
# [CV 1/5; 32/32] END criterion=entropy, max_depth=7, n_estimators=400;, score=0.876 total time=   1.1s
# [CV 2/5; 32/32] START criterion=entropy, max_depth=7, n_estimators=400..........
# [CV 2/5; 32/32] END criterion=entropy, max_depth=7, n_estimators=400;, score=0.853 total time=   1.2s
# [CV 3/5; 32/32] START criterion=entropy, max_depth=7, n_estimators=400..........
# [CV 3/5; 32/32] END criterion=entropy, max_depth=7, n_estimators=400;, score=0.865 total time=   0.9s
# [CV 4/5; 32/32] START criterion=entropy, max_depth=7, n_estimators=400..........
# [CV 4/5; 32/32] END criterion=entropy, max_depth=7, n_estimators=400;, score=0.874 total time=   0.8s
# [CV 5/5; 32/32] START criterion=entropy, max_depth=7, n_estimators=400..........
# [CV 5/5; 32/32] END criterion=entropy, max_depth=7, n_estimators=400;, score=0.862 total time=   1.2s
# best score 0.8670588235294117
# best params
# {'bootstrap': True, 'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'entropy', 'max_depth': 7, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 200, 'n_jobs': -1, 'oob_score': False, 'random_state': None, 'verbose': 0, 'warm_start': False}

# %% [markdown]
# ## Random Search

# %%
from sklearn.model_selection import RandomizedSearchCV

classifier = RandomForestClassifier(n_jobs=-1)
param_grid = {
    'n_estimators': np.arange(100, 1500, 100),
    'max_depth': [1, 3, 5, 7],
    'criterion': ['gini', 'entropy']
}

model = RandomizedSearchCV(
    estimator=classifier,
    param_distributions=param_grid,
    n_iter=10,
    scoring='accuracy',
    verbose=10,
    cv=5
)

model.fit(X_train, y_train)

print("best score " + str(model.best_score_))

print('best params')
print(model.best_estimator_.get_params())
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5; 1/10] START criterion=entropy, max_depth=1, n_estimators=1200..........
# [CV 1/5; 1/10] END criterion=entropy, max_depth=1, n_estimators=1200;, score=0.541 total time=   0.7s
# [CV 2/5; 1/10] START criterion=entropy, max_depth=1, n_estimators=1200..........
# [CV 2/5; 1/10] END criterion=entropy, max_depth=1, n_estimators=1200;, score=0.582 total time=   1.0s
# [CV 3/5; 1/10] START criterion=entropy, max_depth=1, n_estimators=1200..........
# [CV 3/5; 1/10] END criterion=entropy, max_depth=1, n_estimators=1200;, score=0.553 total time=   0.9s
# [CV 4/5; 1/10] START criterion=entropy, max_depth=1, n_estimators=1200..........
# [CV 4/5; 1/10] END criterion=entropy, max_depth=1, n_estimators=1200;, score=0.565 total time=   0.7s
# [CV 5/5; 1/10] START criterion=entropy, max_depth=1, n_estimators=1200..........
# [CV 5/5; 1/10] END criterion=entropy, max_depth=1, n_estimators=1200;, score=0.518 total time=   0.7s
# [CV 1/5; 2/10] START criterion=entropy, max_depth=3, n_estimators=100...........
# [CV 1/5; 2/10] END criterion=entropy, max_depth=3, n_estimators=100;, score=0.732 total time=   0.0s
# [CV 2/5; 2/10] START criterion=entropy, max_depth=3, n_estimators=100...........
# [CV 2/5; 2/10] END criterion=entropy, max_depth=3, n_estimators=100;, score=0.732 total time=   0.0s
# [CV 3/5; 2/10] START criterion=entropy, max_depth=3, n_estimators=100...........
# [CV 3/5; 2/10] END criterion=entropy, max_depth=3, n_estimators=100;, score=0.747 total time=   0.0s
# [CV 4/5; 2/10] START criterion=entropy, max_depth=3, n_estimators=100...........
# [CV 4/5; 2/10] END criterion=entropy, max_depth=3, n_estimators=100;, score=0.826 total time=   0.0s
# [CV 5/5; 2/10] START criterion=entropy, max_depth=3, n_estimators=100...........
# [CV 5/5; 2/10] END criterion=entropy, max_depth=3, n_estimators=100;, score=0.750 total time=   0.0s
# [CV 1/5; 3/10] START criterion=entropy, max_depth=7, n_estimators=800...........
# [CV 1/5; 3/10] END criterion=entropy, max_depth=7, n_estimators=800;, score=0.876 total time=   0.8s
# [CV 2/5; 3/10] START criterion=entropy, max_depth=7, n_estimators=800...........
# [CV 2/5; 3/10] END criterion=entropy, max_depth=7, n_estimators=800;, score=0.856 total time=   0.8s
# [CV 3/5; 3/10] START criterion=entropy, max_depth=7, n_estimators=800...........
# [CV 3/5; 3/10] END criterion=entropy, max_depth=7, n_estimators=800;, score=0.850 total time=   0.8s
# [CV 4/5; 3/10] START criterion=entropy, max_depth=7, n_estimators=800...........
# [CV 4/5; 3/10] END criterion=entropy, max_depth=7, n_estimators=800;, score=0.891 total time=   0.8s
# [CV 5/5; 3/10] START criterion=entropy, max_depth=7, n_estimators=800...........
# [CV 5/5; 3/10] END criterion=entropy, max_depth=7, n_estimators=800;, score=0.856 total time=   0.8s
# [CV 1/5; 4/10] START criterion=gini, max_depth=5, n_estimators=1000.............
# [CV 1/5; 4/10] END criterion=gini, max_depth=5, n_estimators=1000;, score=0.838 total time=   0.8s
# [CV 2/5; 4/10] START criterion=gini, max_depth=5, n_estimators=1000.............
# [CV 2/5; 4/10] END criterion=gini, max_depth=5, n_estimators=1000;, score=0.818 total time=   0.9s
# [CV 3/5; 4/10] START criterion=gini, max_depth=5, n_estimators=1000.............
# [CV 3/5; 4/10] END criterion=gini, max_depth=5, n_estimators=1000;, score=0.826 total time=   0.8s
# [CV 4/5; 4/10] START criterion=gini, max_depth=5, n_estimators=1000.............
# [CV 4/5; 4/10] END criterion=gini, max_depth=5, n_estimators=1000;, score=0.847 total time=   0.8s
# [CV 5/5; 4/10] START criterion=gini, max_depth=5, n_estimators=1000.............
# [CV 5/5; 4/10] END criterion=gini, max_depth=5, n_estimators=1000;, score=0.824 total time=   0.7s
# [CV 1/5; 5/10] START criterion=entropy, max_depth=5, n_estimators=100...........
# [CV 1/5; 5/10] END criterion=entropy, max_depth=5, n_estimators=100;, score=0.847 total time=   0.0s
# [CV 2/5; 5/10] START criterion=entropy, max_depth=5, n_estimators=100...........
# [CV 2/5; 5/10] END criterion=entropy, max_depth=5, n_estimators=100;, score=0.841 total time=   0.0s
# [CV 3/5; 5/10] START criterion=entropy, max_depth=5, n_estimators=100...........
# [CV 3/5; 5/10] END criterion=entropy, max_depth=5, n_estimators=100;, score=0.832 total time=   0.0s
# [CV 4/5; 5/10] START criterion=entropy, max_depth=5, n_estimators=100...........
# [CV 4/5; 5/10] END criterion=entropy, max_depth=5, n_estimators=100;, score=0.829 total time=   0.0s
# [CV 5/5; 5/10] START criterion=entropy, max_depth=5, n_estimators=100...........
# [CV 5/5; 5/10] END criterion=entropy, max_depth=5, n_estimators=100;, score=0.815 total time=   0.0s
# [CV 1/5; 6/10] START criterion=gini, max_depth=5, n_estimators=200..............
# [CV 1/5; 6/10] END criterion=gini, max_depth=5, n_estimators=200;, score=0.841 total time=   0.1s
# [CV 2/5; 6/10] START criterion=gini, max_depth=5, n_estimators=200..............
# [CV 2/5; 6/10] END criterion=gini, max_depth=5, n_estimators=200;, score=0.803 total time=   0.1s
# [CV 3/5; 6/10] START criterion=gini, max_depth=5, n_estimators=200..............
# [CV 3/5; 6/10] END criterion=gini, max_depth=5, n_estimators=200;, score=0.826 total time=   0.2s
# [CV 4/5; 6/10] START criterion=gini, max_depth=5, n_estimators=200..............
# [CV 4/5; 6/10] END criterion=gini, max_depth=5, n_estimators=200;, score=0.841 total time=   0.1s
# [CV 5/5; 6/10] START criterion=gini, max_depth=5, n_estimators=200..............
# [CV 5/5; 6/10] END criterion=gini, max_depth=5, n_estimators=200;, score=0.826 total time=   0.1s
# [CV 1/5; 7/10] START criterion=gini, max_depth=3, n_estimators=1200.............
# [CV 1/5; 7/10] END criterion=gini, max_depth=3, n_estimators=1200;, score=0.806 total time=   0.8s
# [CV 2/5; 7/10] START criterion=gini, max_depth=3, n_estimators=1200.............
# [CV 2/5; 7/10] END criterion=gini, max_depth=3, n_estimators=1200;, score=0.779 total time=   0.8s
# [CV 3/5; 7/10] START criterion=gini, max_depth=3, n_estimators=1200.............
# [CV 3/5; 7/10] END criterion=gini, max_depth=3, n_estimators=1200;, score=0.776 total time=   0.8s
# [CV 4/5; 7/10] START criterion=gini, max_depth=3, n_estimators=1200.............
# [CV 4/5; 7/10] END criterion=gini, max_depth=3, n_estimators=1200;, score=0.809 total time=   0.8s
# [CV 5/5; 7/10] START criterion=gini, max_depth=3, n_estimators=1200.............
# [CV 5/5; 7/10] END criterion=gini, max_depth=3, n_estimators=1200;, score=0.800 total time=   0.8s
# [CV 1/5; 8/10] START criterion=gini, max_depth=3, n_estimators=1400.............
# [CV 1/5; 8/10] END criterion=gini, max_depth=3, n_estimators=1400;, score=0.815 total time=   0.9s
# [CV 2/5; 8/10] START criterion=gini, max_depth=3, n_estimators=1400.............
# [CV 2/5; 8/10] END criterion=gini, max_depth=3, n_estimators=1400;, score=0.776 total time=   0.9s
# [CV 3/5; 8/10] START criterion=gini, max_depth=3, n_estimators=1400.............
# [CV 3/5; 8/10] END criterion=gini, max_depth=3, n_estimators=1400;, score=0.779 total time=   0.9s
# [CV 4/5; 8/10] START criterion=gini, max_depth=3, n_estimators=1400.............
# [CV 4/5; 8/10] END criterion=gini, max_depth=3, n_estimators=1400;, score=0.812 total time=   0.9s
# [CV 5/5; 8/10] START criterion=gini, max_depth=3, n_estimators=1400.............
# [CV 5/5; 8/10] END criterion=gini, max_depth=3, n_estimators=1400;, score=0.800 total time=   0.9s
# [CV 1/5; 9/10] START criterion=gini, max_depth=1, n_estimators=400..............
# [CV 1/5; 9/10] END criterion=gini, max_depth=1, n_estimators=400;, score=0.635 total time=   0.4s
# [CV 2/5; 9/10] START criterion=gini, max_depth=1, n_estimators=400..............
# [CV 2/5; 9/10] END criterion=gini, max_depth=1, n_estimators=400;, score=0.679 total time=   0.2s
# [CV 3/5; 9/10] START criterion=gini, max_depth=1, n_estimators=400..............
# [CV 3/5; 9/10] END criterion=gini, max_depth=1, n_estimators=400;, score=0.556 total time=   0.2s
# [CV 4/5; 9/10] START criterion=gini, max_depth=1, n_estimators=400..............
# [CV 4/5; 9/10] END criterion=gini, max_depth=1, n_estimators=400;, score=0.641 total time=   0.2s
# [CV 5/5; 9/10] START criterion=gini, max_depth=1, n_estimators=400..............
# [CV 5/5; 9/10] END criterion=gini, max_depth=1, n_estimators=400;, score=0.585 total time=   0.2s
# [CV 1/5; 10/10] START criterion=entropy, max_depth=3, n_estimators=1000.........
# [CV 1/5; 10/10] END criterion=entropy, max_depth=3, n_estimators=1000;, score=0.774 total time=   0.7s
# [CV 2/5; 10/10] START criterion=entropy, max_depth=3, n_estimators=1000.........
# [CV 2/5; 10/10] END criterion=entropy, max_depth=3, n_estimators=1000;, score=0.806 total time=   0.7s
# [CV 3/5; 10/10] START criterion=entropy, max_depth=3, n_estimators=1000.........
# [CV 3/5; 10/10] END criterion=entropy, max_depth=3, n_estimators=1000;, score=0.776 total time=   0.7s
# [CV 4/5; 10/10] START criterion=entropy, max_depth=3, n_estimators=1000.........
# [CV 4/5; 10/10] END criterion=entropy, max_depth=3, n_estimators=1000;, score=0.812 total time=   0.7s
# [CV 5/5; 10/10] START criterion=entropy, max_depth=3, n_estimators=1000.........
# [CV 5/5; 10/10] END criterion=entropy, max_depth=3, n_estimators=1000;, score=0.771 total time=   0.7s
# best score 0.8658823529411764
# best params
# {'bootstrap': True, 'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'entropy', 'max_depth': 7, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 800, 'n_jobs': -1, 'oob_score': False, 'random_state': None, 'verbose': 0, 'warm_start': False}

# %% [markdown]
# ## Grid/Random Search with Pipelines

# %%
from sklearn import decomposition
from sklearn import preprocessing
from sklearn import pipeline

scl = preprocessing.StandardScaler()
pca = decomposition.PCA()

rf = RandomForestClassifier(n_jobs=-1)

classifier = pipeline.Pipeline(
    [
        ('scaling', scl),
        ('pca', pca),
        ('rf', rf)
    ]
)

param_grid = {
    'pca__n_components': np.arange(5, 10),
    'rf__n_estimators': np.arange(100, 1500, 100),
    'rf__max_depth': np.arange(1,20,5),
    'rf__criterion': ['gini', 'entropy']
}

model = RandomizedSearchCV(
    estimator=classifier,
    param_distributions=param_grid,
    n_iter=10,
    scoring='accuracy',
    verbose=10,
    cv=5
)

model.fit(X_train, y_train)

print("best score " + str(model.best_score_))

print('best params')
print(model.best_estimator_.get_params())
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5; 1/10] START pca__n_components=9, rf__criterion=gini, rf__max_depth=6, rf__n_estimators=100
# [CV 1/5; 1/10] END pca__n_components=9, rf__criterion=gini, rf__max_depth=6, rf__n_estimators=100;, score=0.421 total time=   4.8s
# [CV 2/5; 1/10] START pca__n_components=9, rf__criterion=gini, rf__max_depth=6, rf__n_estimators=100
# [CV 2/5; 1/10] END pca__n_components=9, rf__criterion=gini, rf__max_depth=6, rf__n_estimators=100;, score=0.471 total time=   0.1s
# [CV 3/5; 1/10] START pca__n_components=9, rf__criterion=gini, rf__max_depth=6, rf__n_estimators=100
# [CV 3/5; 1/10] END pca__n_components=9, rf__criterion=gini, rf__max_depth=6, rf__n_estimators=100;, score=0.432 total time=   0.1s
# [CV 4/5; 1/10] START pca__n_components=9, rf__criterion=gini, rf__max_depth=6, rf__n_estimators=100
# [CV 4/5; 1/10] END pca__n_components=9, rf__criterion=gini, rf__max_depth=6, rf__n_estimators=100;, score=0.441 total time=   0.1s
# [CV 5/5; 1/10] START pca__n_components=9, rf__criterion=gini, rf__max_depth=6, rf__n_estimators=100
# [CV 5/5; 1/10] END pca__n_components=9, rf__criterion=gini, rf__max_depth=6, rf__n_estimators=100;, score=0.450 total time=   0.1s
# [CV 1/5; 2/10] START pca__n_components=8, rf__criterion=entropy, rf__max_depth=16, rf__n_estimators=1400
# [CV 1/5; 2/10] END pca__n_components=8, rf__criterion=entropy, rf__max_depth=16, rf__n_estimators=1400;, score=0.353 total time=   2.9s
# [CV 2/5; 2/10] START pca__n_components=8, rf__criterion=entropy, rf__max_depth=16, rf__n_estimators=1400
# [CV 2/5; 2/10] END pca__n_components=8, rf__criterion=entropy, rf__max_depth=16, rf__n_estimators=1400;, score=0.447 total time=   2.9s
# [CV 3/5; 2/10] START pca__n_components=8, rf__criterion=entropy, rf__max_depth=16, rf__n_estimators=1400
# [CV 3/5; 2/10] END pca__n_components=8, rf__criterion=entropy, rf__max_depth=16, rf__n_estimators=1400;, score=0.415 total time=   2.8s
# [CV 4/5; 2/10] START pca__n_components=8, rf__criterion=entropy, rf__max_depth=16, rf__n_estimators=1400
# [CV 4/5; 2/10] END pca__n_components=8, rf__criterion=entropy, rf__max_depth=16, rf__n_estimators=1400;, score=0.424 total time=   2.9s
# [CV 5/5; 2/10] START pca__n_components=8, rf__criterion=entropy, rf__max_depth=16, rf__n_estimators=1400
# [CV 5/5; 2/10] END pca__n_components=8, rf__criterion=entropy, rf__max_depth=16, rf__n_estimators=1400;, score=0.459 total time=   2.9s
# [CV 1/5; 3/10] START pca__n_components=7, rf__criterion=gini, rf__max_depth=1, rf__n_estimators=1200
# [CV 1/5; 3/10] END pca__n_components=7, rf__criterion=gini, rf__max_depth=1, rf__n_estimators=1200;, score=0.385 total time=   0.8s
# [CV 2/5; 3/10] START pca__n_components=7, rf__criterion=gini, rf__max_depth=1, rf__n_estimators=1200
# [CV 2/5; 3/10] END pca__n_components=7, rf__criterion=gini, rf__max_depth=1, rf__n_estimators=1200;, score=0.421 total time=   0.8s
# [CV 3/5; 3/10] START pca__n_components=7, rf__criterion=gini, rf__max_depth=1, rf__n_estimators=1200
# [CV 3/5; 3/10] END pca__n_components=7, rf__criterion=gini, rf__max_depth=1, rf__n_estimators=1200;, score=0.426 total time=   0.8s
# [CV 4/5; 3/10] START pca__n_components=7, rf__criterion=gini, rf__max_depth=1, rf__n_estimators=1200
# [CV 4/5; 3/10] END pca__n_components=7, rf__criterion=gini, rf__max_depth=1, rf__n_estimators=1200;, score=0.421 total time=   0.8s
# [CV 5/5; 3/10] START pca__n_components=7, rf__criterion=gini, rf__max_depth=1, rf__n_estimators=1200
# [CV 5/5; 3/10] END pca__n_components=7, rf__criterion=gini, rf__max_depth=1, rf__n_estimators=1200;, score=0.362 total time=   0.8s
# [CV 1/5; 4/10] START pca__n_components=6, rf__criterion=entropy, rf__max_depth=16, rf__n_estimators=100
# [CV 1/5; 4/10] END pca__n_components=6, rf__criterion=entropy, rf__max_depth=16, rf__n_estimators=100;, score=0.332 total time=   0.2s
# [CV 2/5; 4/10] START pca__n_components=6, rf__criterion=entropy, rf__max_depth=16, rf__n_estimators=100
# [CV 2/5; 4/10] END pca__n_components=6, rf__criterion=entropy, rf__max_depth=16, rf__n_estimators=100;, score=0.356 total time=   0.2s
# [CV 3/5; 4/10] START pca__n_components=6, rf__criterion=entropy, rf__max_depth=16, rf__n_estimators=100
# [CV 3/5; 4/10] END pca__n_components=6, rf__criterion=entropy, rf__max_depth=16, rf__n_estimators=100;, score=0.391 total time=   0.2s
# [CV 4/5; 4/10] START pca__n_components=6, rf__criterion=entropy, rf__max_depth=16, rf__n_estimators=100
# [CV 4/5; 4/10] END pca__n_components=6, rf__criterion=entropy, rf__max_depth=16, rf__n_estimators=100;, score=0.365 total time=   0.2s
# [CV 5/5; 4/10] START pca__n_components=6, rf__criterion=entropy, rf__max_depth=16, rf__n_estimators=100
# [CV 5/5; 4/10] END pca__n_components=6, rf__criterion=entropy, rf__max_depth=16, rf__n_estimators=100;, score=0.312 total time=   0.2s
# [CV 1/5; 5/10] START pca__n_components=8, rf__criterion=entropy, rf__max_depth=1, rf__n_estimators=800
# [CV 1/5; 5/10] END pca__n_components=8, rf__criterion=entropy, rf__max_depth=1, rf__n_estimators=800;, score=0.379 total time=   0.6s
# [CV 2/5; 5/10] START pca__n_components=8, rf__criterion=entropy, rf__max_depth=1, rf__n_estimators=800
# [CV 2/5; 5/10] END pca__n_components=8, rf__criterion=entropy, rf__max_depth=1, rf__n_estimators=800;, score=0.432 total time=   0.5s
# [CV 3/5; 5/10] START pca__n_components=8, rf__criterion=entropy, rf__max_depth=1, rf__n_estimators=800
# [CV 3/5; 5/10] END pca__n_components=8, rf__criterion=entropy, rf__max_depth=1, rf__n_estimators=800;, score=0.406 total time=   0.6s
# [CV 4/5; 5/10] START pca__n_components=8, rf__criterion=entropy, rf__max_depth=1, rf__n_estimators=800
# [CV 4/5; 5/10] END pca__n_components=8, rf__criterion=entropy, rf__max_depth=1, rf__n_estimators=800;, score=0.412 total time=   0.6s
# [CV 5/5; 5/10] START pca__n_components=8, rf__criterion=entropy, rf__max_depth=1, rf__n_estimators=800
# [CV 5/5; 5/10] END pca__n_components=8, rf__criterion=entropy, rf__max_depth=1, rf__n_estimators=800;, score=0.432 total time=   0.6s
# [CV 1/5; 6/10] START pca__n_components=6, rf__criterion=entropy, rf__max_depth=1, rf__n_estimators=900
# [CV 1/5; 6/10] END pca__n_components=6, rf__criterion=entropy, rf__max_depth=1, rf__n_estimators=900;, score=0.391 total time=   0.7s
# [CV 2/5; 6/10] START pca__n_components=6, rf__criterion=entropy, rf__max_depth=1, rf__n_estimators=900
# [CV 2/5; 6/10] END pca__n_components=6, rf__criterion=entropy, rf__max_depth=1, rf__n_estimators=900;, score=0.379 total time=   0.7s
# [CV 3/5; 6/10] START pca__n_components=6, rf__criterion=entropy, rf__max_depth=1, rf__n_estimators=900
# [CV 3/5; 6/10] END pca__n_components=6, rf__criterion=entropy, rf__max_depth=1, rf__n_estimators=900;, score=0.418 total time=   0.7s
# [CV 4/5; 6/10] START pca__n_components=6, rf__criterion=entropy, rf__max_depth=1, rf__n_estimators=900
# [CV 4/5; 6/10] END pca__n_components=6, rf__criterion=entropy, rf__max_depth=1, rf__n_estimators=900;, score=0.424 total time=   0.7s
# [CV 5/5; 6/10] START pca__n_components=6, rf__criterion=entropy, rf__max_depth=1, rf__n_estimators=900
# [CV 5/5; 6/10] END pca__n_components=6, rf__criterion=entropy, rf__max_depth=1, rf__n_estimators=900;, score=0.341 total time=   0.7s
# [CV 1/5; 7/10] START pca__n_components=7, rf__criterion=gini, rf__max_depth=1, rf__n_estimators=1400
# [CV 1/5; 7/10] END pca__n_components=7, rf__criterion=gini, rf__max_depth=1, rf__n_estimators=1400;, score=0.374 total time=   1.1s
# [CV 2/5; 7/10] START pca__n_components=7, rf__criterion=gini, rf__max_depth=1, rf__n_estimators=1400
# [CV 2/5; 7/10] END pca__n_components=7, rf__criterion=gini, rf__max_depth=1, rf__n_estimators=1400;, score=0.429 total time=   0.9s
# [CV 3/5; 7/10] START pca__n_components=7, rf__criterion=gini, rf__max_depth=1, rf__n_estimators=1400
# [CV 3/5; 7/10] END pca__n_components=7, rf__criterion=gini, rf__max_depth=1, rf__n_estimators=1400;, score=0.421 total time=   0.9s
# [CV 4/5; 7/10] START pca__n_components=7, rf__criterion=gini, rf__max_depth=1, rf__n_estimators=1400
# [CV 4/5; 7/10] END pca__n_components=7, rf__criterion=gini, rf__max_depth=1, rf__n_estimators=1400;, score=0.450 total time=   0.9s
# [CV 5/5; 7/10] START pca__n_components=7, rf__criterion=gini, rf__max_depth=1, rf__n_estimators=1400
# [CV 5/5; 7/10] END pca__n_components=7, rf__criterion=gini, rf__max_depth=1, rf__n_estimators=1400;, score=0.368 total time=   0.9s
# [CV 1/5; 8/10] START pca__n_components=8, rf__criterion=entropy, rf__max_depth=11, rf__n_estimators=600
# [CV 1/5; 8/10] END pca__n_components=8, rf__criterion=entropy, rf__max_depth=11, rf__n_estimators=600;, score=0.338 total time=   1.2s
# [CV 2/5; 8/10] START pca__n_components=8, rf__criterion=entropy, rf__max_depth=11, rf__n_estimators=600
# [CV 2/5; 8/10] END pca__n_components=8, rf__criterion=entropy, rf__max_depth=11, rf__n_estimators=600;, score=0.459 total time=   1.4s
# [CV 3/5; 8/10] START pca__n_components=8, rf__criterion=entropy, rf__max_depth=11, rf__n_estimators=600
# [CV 3/5; 8/10] END pca__n_components=8, rf__criterion=entropy, rf__max_depth=11, rf__n_estimators=600;, score=0.429 total time=   1.5s
# [CV 4/5; 8/10] START pca__n_components=8, rf__criterion=entropy, rf__max_depth=11, rf__n_estimators=600
# [CV 4/5; 8/10] END pca__n_components=8, rf__criterion=entropy, rf__max_depth=11, rf__n_estimators=600;, score=0.429 total time=   1.4s
# [CV 5/5; 8/10] START pca__n_components=8, rf__criterion=entropy, rf__max_depth=11, rf__n_estimators=600
# [CV 5/5; 8/10] END pca__n_components=8, rf__criterion=entropy, rf__max_depth=11, rf__n_estimators=600;, score=0.479 total time=   1.4s
# [CV 1/5; 9/10] START pca__n_components=7, rf__criterion=gini, rf__max_depth=1, rf__n_estimators=200
# [CV 1/5; 9/10] END pca__n_components=7, rf__criterion=gini, rf__max_depth=1, rf__n_estimators=200;, score=0.374 total time=   0.2s
# [CV 2/5; 9/10] START pca__n_components=7, rf__criterion=gini, rf__max_depth=1, rf__n_estimators=200
# [CV 2/5; 9/10] END pca__n_components=7, rf__criterion=gini, rf__max_depth=1, rf__n_estimators=200;, score=0.424 total time=   0.2s
# [CV 3/5; 9/10] START pca__n_components=7, rf__criterion=gini, rf__max_depth=1, rf__n_estimators=200
# [CV 3/5; 9/10] END pca__n_components=7, rf__criterion=gini, rf__max_depth=1, rf__n_estimators=200;, score=0.426 total time=   0.2s
# [CV 4/5; 9/10] START pca__n_components=7, rf__criterion=gini, rf__max_depth=1, rf__n_estimators=200
# [CV 4/5; 9/10] END pca__n_components=7, rf__criterion=gini, rf__max_depth=1, rf__n_estimators=200;, score=0.424 total time=   0.2s
# [CV 5/5; 9/10] START pca__n_components=7, rf__criterion=gini, rf__max_depth=1, rf__n_estimators=200
# [CV 5/5; 9/10] END pca__n_components=7, rf__criterion=gini, rf__max_depth=1, rf__n_estimators=200;, score=0.379 total time=   0.2s
# [CV 1/5; 10/10] START pca__n_components=6, rf__criterion=entropy, rf__max_depth=6, rf__n_estimators=1200
# [CV 1/5; 10/10] END pca__n_components=6, rf__criterion=entropy, rf__max_depth=6, rf__n_estimators=1200;, score=0.341 total time=   2.1s
# [CV 2/5; 10/10] START pca__n_components=6, rf__criterion=entropy, rf__max_depth=6, rf__n_estimators=1200
# [CV 2/5; 10/10] END pca__n_components=6, rf__criterion=entropy, rf__max_depth=6, rf__n_estimators=1200;, score=0.403 total time=   2.1s
# [CV 3/5; 10/10] START pca__n_components=6, rf__criterion=entropy, rf__max_depth=6, rf__n_estimators=1200
# [CV 3/5; 10/10] END pca__n_components=6, rf__criterion=entropy, rf__max_depth=6, rf__n_estimators=1200;, score=0.424 total time=   1.9s
# [CV 4/5; 10/10] START pca__n_components=6, rf__criterion=entropy, rf__max_depth=6, rf__n_estimators=1200
# [CV 4/5; 10/10] END pca__n_components=6, rf__criterion=entropy, rf__max_depth=6, rf__n_estimators=1200;, score=0.441 total time=   2.0s
# [CV 5/5; 10/10] START pca__n_components=6, rf__criterion=entropy, rf__max_depth=6, rf__n_estimators=1200
# [CV 5/5; 10/10] END pca__n_components=6, rf__criterion=entropy, rf__max_depth=6, rf__n_estimators=1200;, score=0.368 total time=   2.0s
# best score 0.4429411764705883
# best params
# {'memory': None, 'steps': [('scaling', StandardScaler()), ('pca', PCA(n_components=9)), ('rf', RandomForestClassifier(max_depth=6, n_jobs=-1))], 'verbose': False, 'scaling': StandardScaler(), 'pca': PCA(n_components=9), 'rf': RandomForestClassifier(max_depth=6, n_jobs=-1), 'scaling__copy': True, 'scaling__with_mean': True, 'scaling__with_std': True, 'pca__copy': True, 'pca__iterated_power': 'auto', 'pca__n_components': 9, 'pca__n_oversamples': 10, 'pca__power_iteration_normalizer': 'auto', 'pca__random_state': None, 'pca__svd_solver': 'auto', 'pca__tol': 0.0, 'pca__whiten': False, 'rf__bootstrap': True, 'rf__ccp_alpha': 0.0, 'rf__class_weight': None, 'rf__criterion': 'gini', 'rf__max_depth': 6, 'rf__max_features': 'sqrt', 'rf__max_leaf_nodes': None, 'rf__max_samples': None, 'rf__min_impurity_decrease': 0.0, 'rf__min_samples_leaf': 1, 'rf__min_samples_split': 2, 'rf__min_weight_fraction_leaf': 0.0, 'rf__n_estimators': 100, 'rf__n_jobs': -1, 'rf__oob_score': False, 'rf__random_state': None, 'rf__verbose': 0, 'rf__warm_start': False}

# %% [markdown]
# ## Bayesian Search

# %%
from sklearn.model_selection import StratifiedKFold
from functools import partial
from skopt import space
from skopt import gp_minimize

def optimise(params, param_names, X, y):
    params = dict(zip(param_names, params))
    model = RandomForestClassifier(**params)
    kf = StratifiedKFold(n_splits=5)
    accuracies = []
    for idx in kf.split(X=X, y=y):
        train_idx, test_idx = idx[0], idx[1]
        
        Xtrain = X[train_idx]
        ytrain = y[train_idx]
        
        Xtest = X[test_idx]
        ytest = y[test_idx]
        
        model.fit(Xtrain, ytrain)
        preds = model.predict(Xtest)
        fold_acc = metrics.accuracy_score(ytest, preds)
        accuracies.append(fold_acc)
        
    # set for minimisation
    return -1.0 * np.mean(accuracies)

param_space = [
    space.Integer(3,15, name="max_depth"),
    space.Integer(100,600, name="n_estimators"),
    space.Categorical(['gini', 'entropy'], name="criterion"),
    space.Real(0.01, 1, prior="uniform", name="max_features")
]
param_names = [
    'max_depth',
    'n_estimators',
    'criterion',
    'max_features'
]

optimization_function = partial(
    optimise,
    param_names=param_names,
    X=X,
    y=y
)

result = gp_minimize(
    optimization_function,
    dimensions=param_space,
    n_calls=15,
    n_random_starts=4,
    verbose=10
)

print(
    dict(
        zip(param_names, result.x)
    )
)
# Out:
# Iteration No: 1 started. Evaluating function at random point.
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 10.3819
# Function value obtained: -0.8995
# Current minimum: -0.8995
# Iteration No: 2 started. Evaluating function at random point.
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 10.6042
# Function value obtained: -0.8810
# Current minimum: -0.8995
# Iteration No: 3 started. Evaluating function at random point.
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 6.6732
# Function value obtained: -0.7645
# Current minimum: -0.8995
# Iteration No: 4 started. Evaluating function at random point.
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 30.4456
# Function value obtained: -0.9050
# Current minimum: -0.9050
# Iteration No: 5 started. Searching for the next optimal point.
# Iteration No: 5 ended. Search finished for the next optimal point.
# Time taken: 2.3993
# Function value obtained: -0.8045
# Current minimum: -0.9050
# Iteration No: 6 started. Searching for the next optimal point.
# Iteration No: 6 ended. Search finished for the next optimal point.
# Time taken: 28.0131
# Function value obtained: -0.9060
# Current minimum: -0.9060
# Iteration No: 7 started. Searching for the next optimal point.
# Iteration No: 7 ended. Search finished for the next optimal point.
# Time taken: 41.5972
# Function value obtained: -0.9085
# Current minimum: -0.9085
# Iteration No: 8 started. Searching for the next optimal point.
# Iteration No: 8 ended. Search finished for the next optimal point.
# Time taken: 45.6601
# Function value obtained: -0.9050
# Current minimum: -0.9085
# Iteration No: 9 started. Searching for the next optimal point.
# Iteration No: 9 ended. Search finished for the next optimal point.
# Time taken: 33.7315
# Function value obtained: -0.9095
# Current minimum: -0.9095
# Iteration No: 10 started. Searching for the next optimal point.
# Iteration No: 10 ended. Search finished for the next optimal point.
# Time taken: 41.9610
# Function value obtained: -0.9060
# Current minimum: -0.9095
# Iteration No: 11 started. Searching for the next optimal point.
# Iteration No: 11 ended. Search finished for the next optimal point.
# Time taken: 19.2922
# Function value obtained: -0.8970
# Current minimum: -0.9095
# Iteration No: 12 started. Searching for the next optimal point.
# Iteration No: 12 ended. Search finished for the next optimal point.
# Time taken: 11.3784
# Function value obtained: -0.7740
# Current minimum: -0.9095
# Iteration No: 13 started. Searching for the next optimal point.
# Iteration No: 13 ended. Search finished for the next optimal point.
# Time taken: 3.8621
# Function value obtained: -0.6375
# Current minimum: -0.9095
# Iteration No: 14 started. Searching for the next optimal point.
# Iteration No: 14 ended. Search finished for the next optimal point.
# Time taken: 2.9149
# Function value obtained: -0.7635
# Current minimum: -0.9095
# Iteration No: 15 started. Searching for the next optimal point.
# Iteration No: 15 ended. Search finished for the next optimal point.
# Time taken: 23.1850
# Function value obtained: -0.9030
# Current minimum: -0.9095
# {'max_depth': 10, 'n_estimators': 600, 'criterion': 'entropy', 'max_features': 0.7137803173426216}

# %% [markdown]
# ## Hyperopt
#
# - https://hyperopt.github.io/hyperopt/
# - https://machinelearningmastery.com/hyperopt-for-automated-machine-learning-with-scikit-learn/

# %%
from hyperopt import hp, fmin, tpe, Trials
from hyperopt.pyll.base import scope

# hyperopt uses a dict rather than a list - use the docs (above) for dtypes
param_space = {
    'max_depth': scope.int(hp.quniform('max_depth', 3, 15, 1)),
    'n_estimators': scope.int(hp.quniform('n_estimators', 100, 600, 1)),
    'criterion': hp.choice('criterion', ['gini', 'entropy']),
    'max_features': hp.uniform('max_features', 0.01, 1)
}

# param_names = ['max_depth', 'n_estimators', 'criterion', 'max_features']

# optimization_function = partial(optimise, param_names=param_names, X=X, y=y)

trials = Trials()

result = fmin(
    fn=optimization_function,
    space=param_space,
    algo=tpe.suggest,
    max_evals=15,
    trials=trials
)

print(result)
# Out:
#   0%|          | 0/15 [00:00<?, ?trial/s, best loss=?]
# job exception: The 'criterion' parameter of RandomForestClassifier must be a str among {'entropy', 'log_loss', 'gini'}. Got 'max_features' instead.
#   0%|          | 0/15 [00:00<?, ?trial/s, best loss=?]
# ---------------------------------------------------------------------------
# InvalidParameterError                     Traceback (most recent call last)
# Cell In[49], line 18
#      12 # param_names = ['max_depth', 'n_estimators', 'criterion', 'max_features']
#      13
#      14 # optimization_function = partial(optimise, param_names=param_names, X=X, y=y)
#      16 trials = Trials()
# ---> 18 result = fmin(
#      19     fn=optimization_function,
#      20     space=param_space,
#      21     algo=tpe.suggest,
#      22     max_evals=15,
#      23     trials=trials
#      24 )
#      26 print(result)
#
# File c:\Users\jb8\AppData\Local\anaconda3\Lib\site-packages\hyperopt\fmin.py:540, in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     537     fn = __objective_fmin_wrapper(fn)
#     539 if allow_trials_fmin and hasattr(trials, "fmin"):
# --> 540     return trials.fmin(
#     541         fn,
#     542         space,
#     543         algo=algo,
#     544         max_evals=max_evals,
#     545         timeout=timeout,
#     546         loss_threshold=loss_threshold,
#     547         max_queue_len=max_queue_len,
#     548         rstate=rstate,
#     549         pass_expr_memo_ctrl=pass_expr_memo_ctrl,
#     550         verbose=verbose,
#     551         catch_eval_exceptions=catch_eval_exceptions,
#     552         return_argmin=return_argmin,
#     553         show_progressbar=show_progressbar,
#     554         early_stop_fn=early_stop_fn,
#     555         trials_save_file=trials_save_file,
#     556     )
#     558 if trials is None:
#     559     if os.path.exists(trials_save_file):
#
# File c:\Users\jb8\AppData\Local\anaconda3\Lib\site-packages\hyperopt\base.py:671, in Trials.fmin(self, fn, space, algo, max_evals, timeout, loss_threshold, max_queue_len, rstate, verbose, pass_expr_memo_ctrl, catch_eval_exceptions, return_argmin, show_progressbar, early_stop_fn, trials_save_file)
#     666 # -- Stop-gap implementation!
#     667 #    fmin should have been a Trials method in the first place
#     668 #    but for now it's still sitting in another file.
#     669 from .fmin import fmin
# --> 671 return fmin(
#     672     fn,
#     673     space,
#     674     algo=algo,
#     675     max_evals=max_evals,
#     676     timeout=timeout,
#     677     loss_threshold=loss_threshold,
#     678     trials=self,
#     679     rstate=rstate,
#     680     verbose=verbose,
#     681     max_queue_len=max_queue_len,
#     682     allow_trials_fmin=False,  # -- prevent recursion
#     683     pass_expr_memo_ctrl=pass_expr_memo_ctrl,
#     684     catch_eval_exceptions=catch_eval_exceptions,
#     685     return_argmin=return_argmin,
#     686     show_progressbar=show_progressbar,
#     687     early_stop_fn=early_stop_fn,
#     688     trials_save_file=trials_save_file,
#     689 )
#
# File c:\Users\jb8\AppData\Local\anaconda3\Lib\site-packages\hyperopt\fmin.py:586, in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     583 rval.catch_eval_exceptions = catch_eval_exceptions
#     585 # next line is where the fmin is actually executed
# --> 586 rval.exhaust()
#     588 if return_argmin:
#     589     if len(trials.trials) == 0:
#
# File c:\Users\jb8\AppData\Local\anaconda3\Lib\site-packages\hyperopt\fmin.py:364, in FMinIter.exhaust(self)
#     362 def exhaust(self):
#     363     n_done = len(self.trials)
# --> 364     self.run(self.max_evals - n_done, block_until_done=self.asynchronous)
#     365     self.trials.refresh()
#     366     return self
#
# File c:\Users\jb8\AppData\Local\anaconda3\Lib\site-packages\hyperopt\fmin.py:300, in FMinIter.run(self, N, block_until_done)
#     297     time.sleep(self.poll_interval_secs)
#     298 else:
#     299     # -- loop over trials and do the jobs directly
# --> 300     self.serial_evaluate()
#     302 self.trials.refresh()
#     303 if self.trials_save_file != "":
#
# File c:\Users\jb8\AppData\Local\anaconda3\Lib\site-packages\hyperopt\fmin.py:178, in FMinIter.serial_evaluate(self, N)
#     176 ctrl = base.Ctrl(self.trials, current_trial=trial)
#     177 try:
# --> 178     result = self.domain.evaluate(spec, ctrl)
#     179 except Exception as e:
#     180     logger.error("job exception: %s" % str(e))
#
# File c:\Users\jb8\AppData\Local\anaconda3\Lib\site-packages\hyperopt\base.py:892, in Domain.evaluate(self, config, ctrl, attach_attachments)
#     883 else:
#     884     # -- the "work" of evaluating `config` can be written
#     885     #    either into the pyll part (self.expr)
#     886     #    or the normal Python part (self.fn)
#     887     pyll_rval = pyll.rec_eval(
#     888         self.expr,
#     889         memo=memo,
#     890         print_node_on_error=self.rec_eval_print_node_on_error,
#     891     )
# --> 892     rval = self.fn(pyll_rval)
#     894 if isinstance(rval, (float, int, np.number)):
#     895     dict_rval = {"loss": float(rval), "status": STATUS_OK}
#
# Cell In[47], line 20, in optimise(params, param_names, X, y)
#      17 Xtest = X[test_idx]
#      18 ytest = y[test_idx]
# ---> 20 model.fit(Xtrain, ytrain)
#      21 preds = model.predict(Xtest)
#      22 fold_acc = metrics.accuracy_score(ytest, preds)
#
# File c:\Users\jb8\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py:1144, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1139 partial_fit_and_fitted = (
#    1140     fit_method.__name__ == "partial_fit" and _is_fitted(estimator)
#    1141 )
#    1143 if not global_skip_validation and not partial_fit_and_fitted:
# -> 1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
#    1151     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\jb8\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py:637, in BaseEstimator._validate_params(self)
#     629 def _validate_params(self):
#     630     """Validate types and values of constructor parameters
#     631
#     632     The expected type and values must be defined in the `_parameter_constraints`
#    (...)
#     635     accepted constraints.
#     636     """
# --> 637     validate_parameter_constraints(
#     638         self._parameter_constraints,
#     639         self.get_params(deep=False),
#     640         caller_name=self.__class__.__name__,
#     641     )
#
# File c:\Users\jb8\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:95, in validate_parameter_constraints(parameter_constraints, params, caller_name)
#      89 else:
#      90     constraints_str = (
#      91         f"{', '.join([str(c) for c in constraints[:-1]])} or"
#      92         f" {constraints[-1]}"
#      93     )
# ---> 95 raise InvalidParameterError(
#      96     f"The {param_name!r} parameter of {caller_name} must be"
#      97     f" {constraints_str}. Got {param_val!r} instead."
#      98 )
#
# InvalidParameterError: The 'criterion' parameter of RandomForestClassifier must be a str among {'entropy', 'log_loss', 'gini'}. Got 'max_features' instead.
